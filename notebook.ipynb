# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd

# %%
df = pd.read_csv('Celestia.csv')
for index, row in df.iterrows():
    print(f"Claim {index}: {row['claim']}")
    print(f"Truth {index}: {row['truth']}")
    print()
# Out:
# Claim 0: A rematch between The Rock and John Cena is scheduled for WrestleMania 29 .
# Truth 0: The match , and its year long buildup , was broadcast on NBC and later sent to DVD and Blu-Ray , collected under the title of The Rock vs John Cena : Once in a Lifetime. The match was later featured in WWE Best PPV Matches of 2012 as the Most Anticipated WrestleMania Match of All Time. A rematch is scheduled for WrestleMania 29.
#
# Claim 1: Less than 684,000 cases of COVID-19 have been confirmed .
# Truth 1: more than 683,000 cases of COVID-19 have been reported in over 190 countries and territories , resulting in approximately 32,100 deaths .
#
# Claim 2: According to the 2012 census , Mecklenburg County has a population of more than 950 thousand people .
# Truth 2: The population of Mecklenburg County is 969,031 people ( as of the 2012 census estimate ) , making it both the most populated and densely populated county in North Carolina .
#
# ...

# %%
from prompt import debate

PRICING = {
    "gpt-4.1":      (2.00,  8.00),
    "gpt-4.1-mini": (0.40,  1.60),
    "gpt-5.2":      (1.75, 14.00),
    "o3-mini":      (1.10,  4.40),
}

model = "gpt-4.1-mini"
case_number = 5
print(f"internal fact: {df['truth'][case_number]}", f"external claim: {df['claim'][case_number]}")
debate(internal_fact=df['truth'][case_number], external_claim=df['claim'][case_number], model=model)
# Out:
# internal fact: more than 704,000 cases of COVID-19 have been reported in over 190 countries and territories , resulting in approximately 33,200 deaths . external claim: There are more than 703,500 cases of COVID-19 worldwide .
# === Math Abstractor Fact ===
# - Title: COVID-19 Case and Death Counts
# - Math Summary: Reported COVID-19 cases exceed 704,000 across over 190 countries and territories, with approximately 33,200 deaths. The external claim states cases exceed 703,500 worldwide.
# - Reason: The internal fact provides precise counts: >704,000 cases and ~33,200 deaths, which is consistent with the external claim of >703,500 cases.
#
# === Math Abstractor Claim ===
# - Title: COVID-19 Case Count Comparison
# - Math Summary: The internal fact states over 704,000 COVID-19 cases globally, while the external claim states more than 703,500 cases.
# - Reason: Both quantities represent total reported cases worldwide, with the internal figure slightly higher by at least 500 cases.
#
# ...
